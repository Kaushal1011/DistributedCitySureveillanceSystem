# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %%
# Install the Object Detection API
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
cp object_detection/packages/tf2/setup.py .
python -m pip install .
# Out:
# UsageError: Line magic function `%%bash` not found.

# %%
import matplotlib
import matplotlib.pyplot as plt
# !pip install imageio
import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
# from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline
# Out:
# Requirement already satisfied: imageio in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (2.9.0)
# Requirement already satisfied: numpy in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from imageio) (1.18.5)
# Requirement already satisfied: pillow in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from imageio) (8.0.1)

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: a file path.

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  """Wrapper function to visualize detections.

  Args:
    image_np: uint8 numpy array with shape (img_height, img_width, 3)
    boxes: a numpy array of shape [N, 4]
    classes: a numpy array of shape [N]. Note that class indices are 1-based,
      and match the keys in the label map.
    scores: a numpy array of shape [N] or None.  If scores=None, then
      this function assumes that the boxes to be plotted are groundtruth
      boxes and plot all boxes as black with no classes or scores.
    category_index: a dict containing category dictionaries (each holding
      category index `id` and category name `name`) keyed by category indices.
    figsize: size for the figure.
    image_name: a name for the image file.
  """
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

# %%
# Load images and visualize
train_image_dir = 'models/research/object_detection/test_images/guns/'
train_images_np = []
for i in range(1, 32):
  image_path = os.path.join(train_image_dir, str(i) + '.jpeg')
  train_images_np.append(load_image_into_numpy_array(image_path))

plt.rcParams['axes.grid'] = False
plt.rcParams['xtick.labelsize'] = False
plt.rcParams['ytick.labelsize'] = False
plt.rcParams['xtick.top'] = False
plt.rcParams['xtick.bottom'] = False
plt.rcParams['ytick.left'] = False
plt.rcParams['ytick.right'] = False
plt.rcParams['figure.figsize'] = [14, 7]

for idx, train_image_np in enumerate(train_images_np):
  plt.subplot(4, 8, idx+1)
  plt.imshow(train_image_np)
plt.show()

# %%
# !pip install colabutils
# Out:
# Requirement already satisfied: colabutils in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (0.1.3)
# Requirement already satisfied: ipython>=5.5.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from colabutils) (5.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from colabutils) (1.12.8)
# Requirement already satisfied: setuptools>=18.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (50.3.1.post20201107)
# Requirement already satisfied: pickleshare in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (0.7.5)
# Requirement already satisfied: pygments in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (2.7.2)
# Requirement already satisfied: traitlets>=4.2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (5.0.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (0.8.1)
# Requirement already satisfied: decorator in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython>=5.5.0->colabutils) (4.8.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->colabutils) (0.0.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->colabutils) (1.23.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->colabutils) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->colabutils) (3.0.1)
# Collecting google-auth>=1.16.0
#   Downloading google_auth-1.24.0-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 3.0 MB/s eta 0:00:01
# Collecting six<2dev,>=1.13.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: ipython-genutils in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from traitlets>=4.2->ipython>=5.5.0->colabutils) (0.2.0)
# Requirement already satisfied: wcwidth in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.5.0->colabutils) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.5.0->colabutils) (0.6.0)
# Requirement already satisfied: pytz in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (2020.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (1.52.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (2.21.0)
# Requirement already satisfied: protobuf>=3.12.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (3.13.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->colabutils) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->colabutils) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth>=1.16.0->google-api-python-client>=1.6.7->colabutils) (4.6)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->colabutils) (2020.6.20)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client>=1.6.7->colabutils) (0.4.8)
# Installing collected packages: six, google-auth
#   Attempting uninstall: six
#     Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# jupyter-console 6.2.0 requires prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.18 which is incompatible.
# google-colab 1.0.0 requires google-auth~=1.4.0, but you'll have google-auth 1.24.0 which is incompatible.
# google-colab 1.0.0 requires six~=1.12.0, but you'll have six 1.15.0 which is incompatible.
# apache-beam 2.25.0 requires requests<3.0.0,>=2.24.0, but you'll have requests 2.21.0 which is incompatible.
# Successfully installed google-auth-1.24.0 six-1.15.0

# %%
# !pip install google-colab
from object_detection.utils import colab_utils
# Out:
# Requirement already satisfied: google-colab in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: ipykernel~=4.6.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (4.6.1)
# Requirement already satisfied: notebook~=5.2.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (5.2.2)
# Requirement already satisfied: pandas~=0.24.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (0.24.2)
# Requirement already satisfied: portpicker~=1.2.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (1.2.0)
# Requirement already satisfied: tornado~=4.5.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (4.5.3)
# Requirement already satisfied: requests~=2.21.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (2.21.0)
# Requirement already satisfied: ipython~=5.5.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-colab) (5.5.0)
# Collecting six~=1.12.0
#   Using cached six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting google-auth~=1.4.0
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# Requirement already satisfied: traitlets>=4.1.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipykernel~=4.6.0->google-colab) (5.0.5)
# Requirement already satisfied: jupyter-client in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipykernel~=4.6.0->google-colab) (6.1.7)
# Requirement already satisfied: ipython-genutils in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (0.2.0)
# Requirement already satisfied: jinja2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (2.11.2)
# Requirement already satisfied: nbconvert in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (6.0.7)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (0.9.1)
# Requirement already satisfied: nbformat in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (5.0.8)
# Requirement already satisfied: jupyter-core in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from notebook~=5.2.0->google-colab) (4.6.3)
# Requirement already satisfied: pytz>=2011k in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pandas~=0.24.0->google-colab) (2020.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pandas~=0.24.0->google-colab) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pandas~=0.24.0->google-colab) (2.8.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests~=2.21.0->google-colab) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests~=2.21.0->google-colab) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests~=2.21.0->google-colab) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from requests~=2.21.0->google-colab) (2020.6.20)
# Requirement already satisfied: setuptools>=18.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (50.3.1.post20201107)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (4.8.0)
# Requirement already satisfied: decorator in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (4.4.2)
# Requirement already satisfied: pygments in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (2.7.2)
# Requirement already satisfied: pickleshare in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from ipython~=5.5.0->google-colab) (0.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth~=1.4.0->google-colab) (0.2.8)
# Requirement already satisfied: cachetools>=2.0.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth~=1.4.0->google-colab) (4.1.1)
# Requirement already satisfied: rsa>=3.1.4 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from google-auth~=1.4.0->google-colab) (4.6)
# Requirement already satisfied: pyzmq>=13 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from jupyter-client->ipykernel~=4.6.0->google-colab) (19.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from jinja2->notebook~=5.2.0->google-colab) (1.1.1)
# Requirement already satisfied: testpath in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (1.4.3)
# Requirement already satisfied: bleach in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (3.2.1)
# Requirement already satisfied: defusedxml in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.3)
# Requirement already satisfied: ptyprocess in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from terminado>=0.3.3; sys_platform != "win32"->notebook~=5.2.0->google-colab) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbformat->notebook~=5.2.0->google-colab) (3.2.0)
# Requirement already satisfied: wcwidth in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google-colab) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google-colab) (0.4.8)
# Requirement already satisfied: webencodings in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from bleach->nbconvert->notebook~=5.2.0->google-colab) (0.5.1)
# Requirement already satisfied: packaging in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from bleach->nbconvert->notebook~=5.2.0->google-colab) (20.4)
# Requirement already satisfied: nest-asyncio in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook~=5.2.0->google-colab) (1.4.2)
# Requirement already satisfied: async-generator in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook~=5.2.0->google-colab) (1.10)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (20.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (2.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook~=5.2.0->google-colab) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /home/kaypee/miniconda3/envs/ds/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (3.4.0)
# Installing collected packages: six, google-auth
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.24.0
#     Uninstalling google-auth-1.24.0:
#       Successfully uninstalled google-auth-1.24.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# tensorboard 2.3.0 requires google-auth<2,>=1.6.3, but you'll have google-auth 1.4.2 which is incompatible.
# jupyter-console 6.2.0 requires prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.18 which is incompatible.
# google-cloud-bigquery 2.6.1 requires six<2.0.0dev,>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# google-api-python-client 1.12.8 requires google-auth>=1.16.0, but you'll have google-auth 1.4.2 which is incompatible.
# google-api-python-client 1.12.8 requires six<2dev,>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# google-api-core 1.23.0 requires google-auth<2.0dev,>=1.21.1, but you'll have google-auth 1.4.2 which is incompatible.
# google-api-core 1.23.0 requires six>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# apache-beam 2.25.0 requires requests<3.0.0,>=2.24.0, but you'll have requests 2.21.0 which is incompatible.
# Successfully installed google-auth-1.4.2 six-1.12.0

# %%
gt_boxes = []
colab_utils.annotate(train_images_np, box_storage_pointer=gt_boxes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-e21b8f8e4dba> in <module>
#       1 gt_boxes = []
# ----> 2 colab_utils.annotate(train_images_np, box_storage_pointer=gt_boxes)
#
# ~/miniconda3/envs/ds/lib/python3.7/site-packages/object_detection/utils/colab_utils.py in annotate(imgs, box_storage_pointer, callbackId)
#     478
#     479   output.register_callback(callbackId, callbackFunction)
# --> 480   draw_bbox(imgs, callbackId)
#
# ~/miniconda3/envs/ds/lib/python3.7/site-packages/object_detection/utils/colab_utils.py in draw_bbox(image_urls, callbackId)
#     378   # call java script function pass string byte array(image_data) as input
#     379   display(js)
# --> 380   eval_js('load_image({}, \'{}\')'.format(image_data, callbackId))
#     381   return
#     382
#
# ~/miniconda3/envs/ds/lib/python3.7/site-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# ~/miniconda3/envs/ds/lib/python3.7/site-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
# !pip --use-feature 2020-resolver
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --no-input                  Disable prompting for input.
#   --proxy <proxy>             Specify a proxy in the form
#                               [user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum number of retries each connection should
#                               attempt (default 5 times).
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to alternate CA bundle.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output
#   --no-python-version-warning
#                               Silence deprecation warnings for upcoming
#                               unsupported Pythons.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.
